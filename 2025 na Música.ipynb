# %%
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/nicolascaseiro/2025-na-Musica/refs/heads/main/2025%20na%20M%C3%BAsica.csv", encoding='utf-8')

df.head()
# Out:
#    #                          Música                  Artista  Popularidade  \
# 0  1                           Tears        Sabrina Carpenter            89
# 1  2                            DtMF                Bad Bunny            92
# 2  3             The Fate of Ophelia             Taylor Swift            98
# 3  4                     Abracadabra                Lady Gaga            81
# 4  5  The Abyss (feat. Lana Del Rey)  The Weeknd,Lana Del Rey            75
#
#    BPM                                            Gêneros  \
# 0  113                                                pop
# 1  136  pop, reggaeton, trap latino, urbano latino, la...
# 2  124                                                pop
# 3  126                                       art pop, pop
# 4   85                                                pop
#
#                     Álbum Data do Álbum Duração  Dançabilidade  ...  Valência  \
# 0       Man’s Best Friend    2025-08-29   02:40             70  ...        49
# 1    DeBÍ TiRAR MáS FOToS    2025-01-05   03:57             63  ...         3
# 2  The Life of a Showgirl    2025-10-03   03:46             73  ...        52
# 3                  MAYHEM    2025-03-07   03:43             68  ...        65
# 4       Hurry Up Tomorrow    2025-01-31   04:42             19  ...         6
#
#    Fala  Ao Vivo  Volume (dB)          Tom  Compasso  Adicionado em  \
# 0     0        0           -5      C Major         4     2025-12-27
# 1     0        0          -27      G Minor         4     2025-12-26
# 2     0       10           -5      F Major         4     2025-12-26
# 3     0       20           -3  A#/B♭ Minor         4     2025-12-26
# 4     0       10           -9      C Minor         4     2025-12-26
#
#                Spotify ID  Camelot          ISRC
# 0  42VUCXerQ5qTr4Qp6PhKo4       8B  USUM72504355
# 1  3sK8wGT43QFpWrvNQsrQya       6A  QMFMF2447070
# 2  53iuhJlwXhSER5J2IYYv1W       7B  USUG12506436
# 3  2LHNTC9QZxsL3nWpt8iaSR       3A  USUM72412581
# 4  5ZDKPFRZC6QlJpf8bCIXTs       5A  USUG12501144
#
# [5 rows x 23 columns]

# %%
linhas, colunas = df.shape[0], df.shape[1]

print(f'Linhas: {linhas}')
print(f'Colunas: {colunas}')
# Out:
# Linhas: 200
# Colunas: 23

# %%
df.describe()
# Out:
#                 #  Popularidade         BPM  Dançabilidade     Energia  \
# count  200.000000    200.000000  200.000000     200.000000  200.000000
# mean   100.500000     64.215000  126.590000      64.180000   68.800000
# std     57.879185     15.202115   25.717872      17.040525   16.515259
# min      1.000000     27.000000   71.000000      16.000000    9.000000
# 25%     50.750000     53.750000  110.000000      54.000000   59.000000
# 50%    100.500000     65.500000  128.000000      66.000000   70.500000
# 75%    150.250000     76.000000  143.250000      77.000000   82.000000
# max    200.000000     98.000000  192.000000      96.000000   98.000000
#
#          Acústica  Instrumentalidade    Valência        Fala     Ao Vivo  \
# count  200.000000         200.000000  200.000000  200.000000  200.000000
# mean    23.875000           1.780000   53.015000    7.900000   16.650000
# std     23.724113           7.128512   23.193197   11.844469   18.869494
# min      0.000000           0.000000    3.000000    0.000000    0.000000
# 25%      5.000000           0.000000   36.000000    0.000000   10.000000
# 50%     16.000000           0.000000   51.000000    0.000000   10.000000
# 75%     38.000000           0.000000   72.000000   10.000000   20.000000
# max     89.000000          52.000000   97.000000   60.000000   90.000000
#
#        Volume (dB)    Compasso
# count   200.000000  200.000000
# mean     -6.020000    3.950000
# std       3.176484    0.240393
# min     -29.000000    3.000000
# 25%      -7.000000    4.000000
# 50%      -6.000000    4.000000
# 75%      -4.000000    4.000000
# max      -2.000000    5.000000

# %%
df.corr(numeric_only=True)
# Out:
#                           #  Popularidade       BPM  Dançabilidade   Energia  \
# #                  1.000000     -0.085955  0.159822       0.240253 -0.077068
# Popularidade      -0.085955      1.000000  0.091252       0.125317 -0.075925
# BPM                0.159822      0.091252  1.000000      -0.027247  0.213346
# Dançabilidade      0.240253      0.125317 -0.027247       1.000000  0.113763
# Energia           -0.077068     -0.075925  0.213346       0.113763  1.000000
# Acústica           0.155711      0.057884 -0.009894      -0.188359 -0.380710
# Instrumentalidade -0.119955     -0.018063 -0.110985      -0.224094  0.037400
# Valência           0.126854     -0.029967  0.114703       0.422182  0.431059
# Fala               0.021844     -0.205673  0.045000       0.116160 -0.002158
# Ao Vivo           -0.053442     -0.078585 -0.014442      -0.125171  0.235684
# Volume (dB)        0.020472      0.121219  0.136704       0.178684  0.730505
# Compasso           0.020586     -0.010794 -0.058604       0.088078  0.002531
#
#                    Acústica  Instrumentalidade  Valência      Fala   Ao Vivo  \
# #                  0.155711          -0.119955  0.126854  0.021844 -0.053442
# Popularidade       0.057884          -0.018063 -0.029967 -0.205673 -0.078585
# BPM               -0.009894          -0.110985  0.114703  0.045000 -0.014442
# Dançabilidade     -0.188359          -0.224094  0.422182  0.116160 -0.125171
# Energia           -0.380710           0.037400  0.431059 -0.002158  0.235684
# Acústica           1.000000          -0.091860 -0.014043  0.031787 -0.062567
# Instrumentalidade -0.091860           1.000000 -0.081497 -0.081084 -0.066401
# Valência          -0.014043          -0.081497  1.000000  0.001030 -0.015500
# Fala               0.031787          -0.081084  0.001030  1.000000  0.026823
# Ao Vivo           -0.062567          -0.066401 -0.015500  0.026823  1.000000
# Volume (dB)       -0.255026          -0.146220  0.348346 -0.037184  0.119603
# Compasso           0.011234           0.043400  0.061423  0.139424 -0.092502
#
#                    Volume (dB)  Compasso
# #                     0.020472  0.020586
# Popularidade          0.121219 -0.010794
# BPM                   0.136704 -0.058604
# Dançabilidade         0.178684  0.088078
# Energia               0.730505  0.002531
# Acústica             -0.255026  0.011234
# Instrumentalidade    -0.146220  0.043400
# Valência              0.348346  0.061423
# Fala                 -0.037184  0.139424
# Ao Vivo               0.119603 -0.092502
# Volume (dB)           1.000000  0.018426
# Compasso              0.018426  1.000000

# %%
colunas_numericas = df.select_dtypes(include=['number']).columns

outliers_bool = pd.DataFrame(False, index=df.index, columns=colunas_numericas)

for col in colunas_numericas:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    limite_inferior = Q1 - 1.5 * IQR
    limite_superior = Q3 + 1.5 * IQR

    outliers_bool[col] = (df[col] < limite_inferior) | (df[col] > limite_superior)

linhas_com_outliers = outliers_bool.any(axis=1)

df_outliers = df[linhas_com_outliers]

print(f"Total de linhas com pelo menos um outlier: {df_outliers.shape[0]}")
# Out:
# Total de linhas com pelo menos um outlier: 78

# %%
def tempo_para_segundos(tempo_str):
    try:
        minutos, segundos = tempo_str.split(':')
        return int(minutos) * 60 + int(segundos)
    except:
        return None

df['Duração_segundos'] = df['Duração'].apply(tempo_para_segundos)

df['Duração_segundos'] = pd.to_numeric(df['Duração_segundos'], errors='coerce')

duracao_numerica = df['Duração_segundos'].dropna()
Q1 = duracao_numerica.quantile(0.25)
Q3 = duracao_numerica.quantile(0.75)
IQR = Q3 - Q1

limite_inferior = Q1 - 1.5 * IQR
limite_superior = Q3 + 1.5 * IQR

outliers = df[(df['Duração_segundos'] < limite_inferior) | (df['Duração_segundos'] > limite_superior)]

print(f"Número de outliers na duração: {outliers.shape[0]}\n")

print(outliers[['Música', 'Artista', 'Duração']])
# Out:
# Número de outliers na duração: 10
#
#                            Música  \
# 22     MOMENTUM (feat. Ilykimchi)
# 53                      Emergence
# 60        Who Believes In Angels?
# 66               Curious Ruminant
# 68                Look Down On Us
# 69                        Nettles
# 82                   A mema praça
# 99   Ta Rico Os Menino Do Gueto 🍀
# 196                     Só Rock 3
# 197                 Favela Vive 6
#
#                                                Artista Duração
# 22                   Skrillex,Zacari,Starrah,Ilykimchi   01:18
# 53                                         Sleep Token   06:26
# 60                           Elton John,Brandi Carlile   05:13
# 66                                         Jethro Tull   06:00
# 68                                              Maruja   09:58
# 69                                          Ethel Cain   08:03
# 82                              Emicida,Rashid,Projota   05:44
# 99   Mc IG,MC Ryan SP,Mc Negão Original,MC GP,DJ DA...   07:39
# 196  Major RD,Borges,MC Cabelinho,Young Ganni,Rock ...   05:12
# 197  ADL,Dexter,Borges,Mc Carol,Sandra De Sá,Lender...   10:43

# %%
colunas = list(df.columns)

colunas.remove('Duração_segundos')

idx = colunas.index('Duração')

colunas.insert(idx + 1, 'Duração_segundos')

df = df[colunas]

media_duracao = df['Duração_segundos'].mean()
minutos = int(media_duracao // 60)
segundos = int(media_duracao % 60)
print(f"Média da duração das músicas: {minutos} min {segundos} seg")
# Out:
# Média da duração das músicas: 3 min 23 seg

# %%
df['BPM'] = pd.to_numeric(df['BPM'], errors='coerce')

bpm_validos = df['BPM'].dropna()

Q1 = bpm_validos.quantile(0.25)
Q3 = bpm_validos.quantile(0.75)
IQR = Q3 - Q1

limite_inferior = Q1 - 1.5 * IQR
limite_superior = Q3 + 1.5 * IQR

outliers_bpm = df[(df['BPM'] < limite_inferior) | (df['BPM'] > limite_superior)]

print(f"Número de outliers de BPM: {outliers_bpm.shape[0]}")
display(outliers_bpm[['Música', 'Artista', 'BPM']])
# Out:
# Número de outliers de BPM: 0
# Empty DataFrame
# Columns: [Música, Artista, BPM]
# Index: []

# %%
media_bpm = df['BPM'].mean()
print(f"Média do BPM: {media_bpm:.2f}")
# Out:
# Média do BPM: 126.59

# %%
df_generos = df.dropna(subset=['Gêneros'])
df_generos['Gêneros_lista'] = df_generos['Gêneros'].apply(lambda x: [g.strip() for g in x.split(',')])
df_exploded = df_generos.explode('Gêneros_lista')

df_exploded.groupby('Gêneros_lista')['Popularidade'].mean().sort_values(ascending=False).head(10)
# Out:
# Gêneros_lista
# trap latino      92.000000
# reggaeton        86.000000
# urbano latino    86.000000
# indie            85.000000
# latino           83.250000
# rage rap         83.000000
# pop soul         80.000000
# trip hop         80.000000
# funk de bh       80.000000
# k-pop            79.285714
# Name: Popularidade, dtype: float64

# %%
df.sort_values(by='Popularidade', ascending=False)[['Música', 'Artista', 'Popularidade']].head(10)
# Out:
#                           Música  \
# 2            The Fate of Ophelia
# 114                       Golden
# 1                           DtMF
# 164  Posso Até Não Te Dar Flores
# 0                          Tears
# 5                        DAISIES
# 113                  like JENNIE
# 121                       Folded
# 29            Sugar On My Tongue
# 117                    undressed
#
#                                                Artista  Popularidade
# 2                                         Taylor Swift            98
# 114  HUNTR/X,EJAE,AUDREY NUNA,REI AMI,KPop Demon Hu...            97
# 1                                            Bad Bunny            92
# 164  DJ Japa NK,MC Meno K,MC Ryan SP,Mc Jacaré,DJ ...            91
# 0                                    Sabrina Carpenter            89
# 5                                        Justin Bieber            89
# 113                                             JENNIE            88
# 121                                            Kehlani            88
# 29                                  Tyler, The Creator            87
# 117                                              sombr            87

# %%
df.sort_values(by='Dançabilidade', ascending=False)[['Música', 'Artista', 'Dançabilidade']].head(10)
# Out:
#                               Música  \
# 119                           d£aler
# 76           BONDE DOS ESTRAGA FESTA
# 167                        FAMOSINHA
# 189       Talvez você precise de mim
# 169             SEQUÊNCIA FEITICEIRA
# 171  Desliza ( Ólhinho  No Corpinho)
# 183                        YES OR NO
# 168        MOTINHA 2.0 (Mete Marcha)
# 164      Posso Até Não Te Dar Flores
# 134                            stick
#
#                                                Artista  Dançabilidade
# 119                                         Lola Young             96
# 76                 Papatinho,Major RD,Mc Carol,CALIFFA             95
# 167          Dj Caio Vieira,MC Meno K,Mc Rodrigo do CN             95
# 189                                Veigh,Supernova Ent             94
# 169  PEDRO SAMPAIO,Mc Gw,Mc Jhey,Mc Rodrigo do CN,M...             93
# 171                                 Léo Santana,Melody             93
# 183                                               Teto             93
# 168                                 DENNIS,Luísa Sonza             91
# 164  DJ Japa NK,MC Meno K,MC Ryan SP,Mc Jacaré,DJ ...             90
# 134                                        Jim Legxacy             90

# %%
df.sort_values(by='Energia', ascending=False)[['Música', 'Artista', 'Energia']].head(10)
# Out:
#                  Música                             Artista  Energia
# 97              ROBOCOP         MC Lan,Criolo,John Dolmayan       98
# 54      infinite source                            Deftones       97
# 67               NOT OK                 5 Seconds of Summer       94
# 41        Magic, Alive!                      McKinley Dixon       94
# 15              My Muse                         Leon Thomas       93
# 18       Here All Night                         Demi Lovato       92
# 50            Drum Show                   Twenty One Pilots       92
# 62         Night Or Day                     Franz Ferdinand       92
# 93           Balacobaco  BaianaSystem,Alice Carvalho,Anitta       92
# 112  Paint Me A Picture                       Magdalena Bay       91

# %%
df.sort_values(by='Valência', ascending=False)[['Música', 'Artista', 'Valência']].head(10)
# Out:
#                               Música  \
# 165                     Mãe Solteira
# 171  Desliza ( Ólhinho  No Corpinho)
# 152                        Vagabundo
# 61                 Basic Being Basic
# 170                           JETSKI
# 21                       THIS IS FOR
# 166                     AMOR BANDIDO
# 92                     Sete Prazeres
# 142                       Lover Girl
# 117                        undressed
#
#                                            Artista  Valência
# 165  DG e Batidão Stronda,Mc Davi,J. Eskine,MC G15        97
# 171                             Léo Santana,Melody        97
# 152                       Gusttavo Lima,Luis Fonsi        95
# 61                                             Djo        94
# 170                 PEDRO SAMPAIO,MC Meno K,Melody        92
# 21                                           TWICE        92
# 166                      J. Eskine,Alef Donk,Oruam        91
# 92                           Seu Jorge,Peu Meurray        90
# 142                                         Laufey        90
# 117                                          sombr        89

# %%
df.sort_values(by='Volume (dB)', ascending=False)[['Música', 'Artista', 'Volume (dB)']].head(10)
# Out:
#                               Música  \
# 62                      Night Or Day
# 15                           My Muse
# 171  Desliza ( Ólhinho  No Corpinho)
# 154                  Eu Me Apaixonei
# 167                        FAMOSINHA
# 23                     LATINA FOREVA
# 3                        Abracadabra
# 7                       Jealous Type
# 67                            NOT OK
# 28                         GiT Ready
#
#                                        Artista  Volume (dB)
# 62                             Franz Ferdinand           -2
# 15                                 Leon Thomas           -2
# 171                         Léo Santana,Melody           -2
# 154                          Vitinho Imperador           -2
# 167  Dj Caio Vieira,MC Meno K,Mc Rodrigo do CN           -2
# 23                                     KAROL G           -3
# 3                                    Lady Gaga           -3
# 7                                     Doja Cat           -3
# 67                         5 Seconds of Summer           -3
# 28                              Nas,DJ Premier           -3

# %%
import seaborn as sns
import matplotlib.pyplot as plt

generos_temp = df['Gêneros'].dropna().apply(lambda x: [g.strip() for g in x.split(',')])
df_temp = df.loc[generos_temp.index].copy()
df_temp['genero'] = generos_temp
df_temp = df_temp.explode('genero')

contagem_generos = df_temp['genero'].value_counts()

plt.figure(figsize=(10,6))
contagem_generos.head(10).plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Top 10 Gêneros Musicais')
plt.ylabel('Quantidade de Músicas')
plt.xlabel('Gêneros')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import matplotlib.ticker as ticker

def formatar_tempo(segundos, pos=None):
    minutos = int(segundos) // 60
    seg = int(segundos) % 60
    return f'{minutos}:{seg:02d}'

plt.figure(figsize=(10, 6))
plt.hist(df['Duração_segundos'].dropna(), bins=30, color='skyblue', edgecolor='black')
plt.title('Distribuição da Duração das Músicas')
plt.xlabel('Duração (min:seg)')
plt.ylabel('Número de Músicas')

ax = plt.gca()
ax.xaxis.set_major_formatter(ticker.FuncFormatter(formatar_tempo))

plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 4))
plt.boxplot(df['Duração_segundos'].dropna(), vert=False)
plt.title('Boxplot da Duração das Músicas')
plt.xlabel('Duração (min:seg)')

ax = plt.gca()
ax.xaxis.set_major_formatter(ticker.FuncFormatter(formatar_tempo))

plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.title('Correlação entre variáveis numéricas')
plt.show()

# %%
meses_pt = ['Janeiro', 'Fevereiro', 'Março', 'Abril', 'Maio', 'Junho',
            'Julho', 'Agosto', 'Setembro', 'Outubro', 'Novembro', 'Dezembro']

df_temp_mes = df.copy()
df_temp_mes['Data do Álbum'] = pd.to_datetime(df_temp_mes['Data do Álbum'], errors='coerce')  # <-- alterado aqui
df_temp_mes['Mês'] = df_temp_mes['Data do Álbum'].dt.month                                     # <-- alterado aqui

popularidade_por_mes = df_temp_mes.groupby('Mês')['Popularidade'].mean()

plt.figure(figsize=(12,6))
popularidade_por_mes.plot(marker='o')
plt.title('Popularidade Média das Músicas por Mês de Lançamento')
plt.xlabel('Mês')
plt.ylabel('Popularidade Média')
plt.grid(True)
plt.xticks(ticks=range(1, 13), labels=meses_pt, rotation=45)
plt.tight_layout()
plt.show()

# %%
pip install streamlit
# Out:
# Requirement already satisfied: streamlit in /usr/local/lib/python3.12/dist-packages (1.52.2)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<7,>=4.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<7,>=4.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (6.2.4)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (8.3.1)
# Requirement already satisfied: numpy<3,>=1.23 in /usr/local/lib/python3.12/dist-packages (from streamlit) (2.0.2)
# Requirement already satisfied: packaging>=20 in /usr/local/lib/python3.12/dist-packages (from streamlit) (25.0)
# Requirement already satisfied: pandas<3,>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (2.2.2)
# Requirement already satisfied: pillow<13,>=7.1.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (11.3.0)
# Requirement already satisfied: protobuf<7,>=3.20 in /usr/local/lib/python3.12/dist-packages (from streamlit) (5.29.5)
# Requirement already satisfied: pyarrow>=7.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (18.1.0)
# Requirement already satisfied: requests<3,>=2.27 in /usr/local/lib/python3.12/dist-packages (from streamlit) (2.32.4)
# Requirement already satisfied: tenacity<10,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (9.1.2)
# Requirement already satisfied: toml<2,>=0.10.1 in /usr/local/lib/python3.12/dist-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (4.15.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in /usr/local/lib/python3.12/dist-packages (from streamlit) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /usr/local/lib/python3.12/dist-packages (from streamlit) (3.1.45)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /usr/local/lib/python3.12/dist-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in /usr/local/lib/python3.12/dist-packages (from streamlit) (6.5.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.12/dist-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (4.25.1)
# Requirement already satisfied: narwhals>=1.14.2 in /usr/local/lib/python3.12/dist-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2.13.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<3,>=1.4.0->streamlit) (2025.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27->streamlit) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27->streamlit) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27->streamlit) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27->streamlit) (2025.11.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.30.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)

# %%
# %%writefile app.py
import streamlit as st
import pandas as pd
import plotly.express as px

st.set_page_config(page_title="Dashboard 2025 na Música", layout="wide")

def carregar_dados():
    url = "https://raw.githubusercontent.com/nicolascaseiro/2025-na-Musica/refs/heads/main/2025%20na%20M%C3%BAsica.csv"
    df = pd.read_csv(url, encoding='utf-8')
    return df

df = carregar_dados()

generos_lista = df['Gêneros'].dropna().apply(lambda x: [g.strip() for g in x.split(',')])
artistas_lista = df['Artista'].dropna().apply(lambda x: [a.strip() for a in x.split(',')])

df_temp = df.copy()
df_temp = df_temp.loc[generos_lista.index]
df_temp = df_temp.assign(Gêneros_lista=generos_lista)
df_temp = df_temp.explode('Gêneros_lista')

artistas_lista_temp = artistas_lista.loc[df_temp.index]
df_temp = df_temp.assign(Artistas_lista=artistas_lista_temp)
df_temp = df_temp.explode('Artistas_lista')

meses_pt = ['Janeiro', 'Fevereiro', 'Março', 'Abril', 'Maio', 'Junho',
            'Julho', 'Agosto', 'Setembro', 'Outubro', 'Novembro', 'Dezembro']

df_temp['Data do Álbum'] = pd.to_datetime(df_temp['Data do Álbum'], errors='coerce')
df_temp['Mês'] = df_temp['Data do Álbum'].dt.month.apply(lambda x: meses_pt[x-1] if pd.notna(x) else None)

st.sidebar.header("Filtros")

def ordenar_meses(meses_selecionados):
    return sorted(meses_selecionados, key=lambda m: meses_pt.index(m))

meses_disponiveis = ordenar_meses(df_temp['Mês'].dropna().unique())
generos_disponiveis = sorted(df_temp['Gêneros_lista'].dropna().unique())
artistas_disponiveis = sorted(df_temp['Artistas_lista'].dropna().unique())

mes_selecionado = st.sidebar.multiselect('Filtrar por Mês:', meses_disponiveis)
genero_selecionado = st.sidebar.multiselect('Filtrar por Gênero:', generos_disponiveis)
artista_selecionado = st.sidebar.multiselect('Filtrar por Artista:', artistas_disponiveis)

df_filtrado = df_temp.copy()

if mes_selecionado:
    df_filtrado = df_filtrado[df_filtrado['Mês'].isin(mes_selecionado)]

if genero_selecionado:
    df_filtrado = df_filtrado[df_filtrado['Gêneros_lista'].isin(genero_selecionado)]

if artista_selecionado:
    df_filtrado = df_filtrado[df_filtrado['Artistas_lista'].isin(artista_selecionado)]

indices_filtrados = df_filtrado.index.unique()
df_tabela = df.loc[indices_filtrados].copy()
df_tabela['Data do Álbum'] = pd.to_datetime(df_tabela['Data do Álbum'], errors='coerce')
df_tabela['Mês'] = df_tabela['Data do Álbum'].dt.month.apply(lambda x: meses_pt[x-1] if pd.notna(x) else None)
total_musicas_filtradas = df_tabela['Música'].nunique()

st.title("Dashboard 2025 na Música")

col1, col2, col3, col4 = st.columns(4)
col1.metric("Total de músicas", total_musicas_filtradas)
col2.metric("Média Popularidade", f"{df_filtrado['Popularidade'].mean():.2f}")
col3.metric("Total de Artistas", df_filtrado['Artistas_lista'].nunique())
col4.metric("Total de Gêneros", df_filtrado['Gêneros_lista'].nunique())

st.markdown("---")

df_grafico = df_filtrado.groupby('Gêneros_lista')['Popularidade'].mean().reset_index()

fig = px.bar(df_grafico,
             x='Gêneros_lista',
             y='Popularidade',
             title='Popularidade Média por Gênero Musical (2024)',
             labels={'Gêneros_lista': 'Gênero', 'Popularidade': 'Popularidade Média'},
             color='Popularidade',
             color_continuous_scale='Viridis',
             text=df_grafico['Popularidade'].round(2)
            )

fig.update_traces(textposition='outside', marker_line_width=1.5, marker_line_color='black')
fig.update_layout(
    plot_bgcolor='white',
    title_font=dict(size=24, family='Verdana', color='darkblue'),
    xaxis_title_font=dict(size=18, family='Verdana'),
    yaxis_title_font=dict(size=18, family='Verdana'),
    xaxis_tickangle=-45,
    xaxis_tickfont=dict(size=12, family='Verdana'),
    yaxis=dict(range=[0, 100]),
    margin=dict(l=40, r=40, t=80, b=100)
)

st.plotly_chart(fig, use_container_width=True)

st.markdown("---")

colunas_exibir = ['Música', 'Artista', 'Gêneros', 'Popularidade', 'Mês']
st.dataframe(df_tabela[colunas_exibir])
# Out:
# Overwriting app.py

# %%
df.head(200)
# Out:
#        #                          Música  \
# 0      1                           Tears
# 1      2                            DtMF
# 2      3             The Fate of Ophelia
# 3      4                     Abracadabra
# 4      5  The Abyss (feat. Lana Del Rey)
# ..   ...                             ...
# 195  196                       RASTAFARI
# 196  197                       Só Rock 3
# 197  198                   Favela Vive 6
# 198  199                    Que Eu Sofra
# 199  200                        A Cidade
#
#                                                Artista  Popularidade  BPM  \
# 0                                    Sabrina Carpenter            89  113
# 1                                            Bad Bunny            92  136
# 2                                         Taylor Swift            98  124
# 3                                            Lady Gaga            81  126
# 4                              The Weeknd,Lana Del Rey            75   85
# ..                                                 ...           ...  ...
# 195                    MC Cabelinho,Palma,Ariel Donato            48  140
# 196  Major RD,Borges,MC Cabelinho,Young Ganni,Rock ...            64  120
# 197  ADL,Dexter,Borges,Mc Carol,Sandra De Sá,Lender...            44   92
# 198                      Baco Exu do Blues,Zeca Veloso            61   94
# 199                                              Lagum            58  154
#
#                                                Gêneros  \
# 0                                                  pop
# 1    pop, reggaeton, trap latino, urbano latino, la...
# 2                                                  pop
# 3                                         art pop, pop
# 4                                                  pop
# ..                                                 ...
# 195  trap brasileiro, trap funk, trap, hip hop bras...
# 196  trap brasileiro, hip hop brasileiro, trap, tra...
# 197  hip hop brasileiro, boom bap, trap brasileiro,...
# 198  hip hop brasileiro, trap brasileiro, mpb, nova...
# 199                        nova mpb, mpb, pop nacional
#
#                                        Álbum Data do Álbum Duração  \
# 0                          Man’s Best Friend    2025-08-29   02:40
# 1                       DeBÍ TiRAR MáS FOToS    2025-01-05   03:57
# 2                     The Life of a Showgirl    2025-10-03   03:46
# 3                                     MAYHEM    2025-03-07   03:43
# 4                          Hurry Up Tomorrow    2025-01-31   04:42
# ..                                       ...           ...     ...
# 195                                   ÊXTASE    2025-09-25   02:07
# 196                                Só Rock 3    2025-02-25   05:12
# 197                            Favela Vive 6    2025-08-06   10:43
# 198                                    HASOS    2025-11-18   03:37
# 199  As Cores, as Curvas e as Dores do Mundo    2025-05-27   02:43
#
#      Duração_segundos  ...  Valência  Fala  Ao Vivo  Volume (dB)          Tom  \
# 0                 160  ...        49     0        0           -5      C Major
# 1                 237  ...         3     0        0          -27      G Minor
# 2                 226  ...        52     0       10           -5      F Major
# 3                 223  ...        65     0       20           -3  A#/B♭ Minor
# 4                 282  ...         6     0       10           -9      C Minor
# ..                ...  ...       ...   ...      ...          ...          ...
# 195               127  ...        75     0       10           -6      G Minor
# 196               312  ...        49    20       10           -3  C♯/D♭ Minor
# 197               643  ...        17    30       20          -11      D Major
# 198               217  ...        29     0       10          -12      B Major
# 199               163  ...        60     0       40           -6      E Major
#
#      Compasso  Adicionado em              Spotify ID Camelot          ISRC
# 0           4     2025-12-27  42VUCXerQ5qTr4Qp6PhKo4      8B  USUM72504355
# 1           4     2025-12-26  3sK8wGT43QFpWrvNQsrQya      6A  QMFMF2447070
# 2           4     2025-12-26  53iuhJlwXhSER5J2IYYv1W      7B  USUG12506436
# 3           4     2025-12-26  2LHNTC9QZxsL3nWpt8iaSR      3A  USUM72412581
# 4           4     2025-12-26  5ZDKPFRZC6QlJpf8bCIXTs      5A  USUG12501144
# ..        ...            ...                     ...     ...           ...
# 195         4     2025-12-27  2tC61vioqodndg6S0P3Nbq      6A  BKLVW2500035
# 196         4     2025-12-27  6QSYz3Nlcxwv1x0RWIgMoj     12A  BXQZW2500001
# 197         4     2025-12-27  6n6loCbiFFkKiGkee41YqO     10B  BXGPM2500001
# 198         3     2025-12-27  2TP9ziZ2BQBLywPLUWdhhf      1B  BX2DO2500001
# 199         3     2025-12-27  6chCkT8RkDC0kM66HKfPQb     12B  BK2Q32500003
#
# [200 rows x 24 columns]

# %%
df.to_csv('2025_na_Musica_final.csv', index=False)
print('DataFrame salvo como 2025_na_Musica_final.csv')
# Out:
# DataFrame salvo como 2025_na_Musica_final.csv
